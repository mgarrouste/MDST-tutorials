# %% [markdown]
# <h1> The Challenge:</h1>
#
# Based off this dataset with school financial, enrollment, and achievement data, we are interested in what information is a useful indicator of student performance at the state level.
#
# This question is a bit too big for a checkpoint, however. Instead, we want you to look at smaller questions related to our overall goal. Here's the overview:
#
# 1. Choose a specific test to focus on
# >Math/Reading for 4/8 grade
# * Pick or create features to use
# >Will all the features be useful in predicting test score? Are some more important than others? Should you standardize, bin, or scale the data?
# * Explore the data as it relates to that test
# >Create 2 well-labeled visualizations (graphs), each with a caption describing the graph and what it tells us about the data
# * Create training and testing data
# >Do you want to train on all the data? Only data from the last 10 years? Only Michigan data?
# * Train a ML model to predict outcome
# >Pick if you want to do a regression or classification task. For both cases, defined _exactly_ what you want to predict, and pick any model in sklearn to use (see sklearn <a href="https://scikit-learn.org/stable/modules/linear_model.html">regressors</a> and <a href="https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html">classifiers</a>).
# * Summarize your findings
# >Write a 1 paragraph summary of what you did and make a recommendation about if and how student performance can be predicted
#
# ** Include comments throughout your code! Every cleanup and preprocessing task should be documented.
#
#
# Of course, if you're finding this assignment interesting (and we really hope you do!), you are welcome to do more than the requirements! For example, you may want to see if expenditure affects 4th graders more than 8th graders. Maybe you want to look into the extended version of this dataset and see how factors like sex and race are involved. You can include all your work in this notebook when you turn it in -- just always make sure you explain what you did and interpret your results. Good luck!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# feel free to import other libraries!

# %%
df = pd.read_csv('../data/states_edu.csv')
df.head()
# Out:
#        PRIMARY_KEY       STATE  YEAR  ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0     1992_ALABAMA     ALABAMA  1992     NaN      2678885.0         304177.0
# 1      1992_ALASKA      ALASKA  1992     NaN      1049591.0         106780.0
# 2     1992_ARIZONA     ARIZONA  1992     NaN      3258079.0         297888.0
# 3    1992_ARKANSAS    ARKANSAS  1992     NaN      1711959.0         178571.0
# 4  1992_CALIFORNIA  CALIFORNIA  1992     NaN     26260025.0        2072470.0
#
#    STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 0      1659028.0       715680.0          2653798.0                1481703.0
# 1       720711.0       222100.0           972488.0                 498362.0
# 2      1369815.0      1590376.0          3401580.0                1435908.0
# 3       958785.0       574603.0          1743022.0                 964323.0
# 4     16546514.0      7641041.0         27138832.0               14358922.0
#
# ...

# %% [markdown]
# Chosen test: Math, 8 grade
# Planning on seeing the influence of revenue and expenditure on these scores

# %% [markdown]
# <h2> Cleanup (optional)</h2>
#
# _Use this space to rename columns, deal with missing data, etc._

# %%
df.isna().sum()
# Out:
# PRIMARY_KEY                        0
# STATE                              0
# YEAR                               0
# ENROLL                           491
# TOTAL_REVENUE                    440
# FEDERAL_REVENUE                  440
# STATE_REVENUE                    440
# LOCAL_REVENUE                    440
# TOTAL_EXPENDITURE                440
# INSTRUCTION_EXPENDITURE          440
# SUPPORT_SERVICES_EXPENDITURE     440
# OTHER_EXPENDITURE                491
# CAPITAL_OUTLAY_EXPENDITURE       440
# GRADES_PK_G                      173
# GRADES_KG_G                       83
# GRADES_4_G                        83
# GRADES_8_G                        83
# GRADES_12_G                       83
# GRADES_1_8_G                     695
# GRADES_9_12_G                    644
# GRADES_ALL_G                      83
# AVG_MATH_4_SCORE                1150
# AVG_MATH_8_SCORE                1113
# AVG_READING_4_SCORE             1065
# AVG_READING_8_SCORE             1153
# dtype: int64

# %%
df.count()
# Out:
# PRIMARY_KEY                     1715
# STATE                           1715
# YEAR                            1715
# ENROLL                          1224
# TOTAL_REVENUE                   1275
# FEDERAL_REVENUE                 1275
# STATE_REVENUE                   1275
# LOCAL_REVENUE                   1275
# TOTAL_EXPENDITURE               1275
# INSTRUCTION_EXPENDITURE         1275
# SUPPORT_SERVICES_EXPENDITURE    1275
# OTHER_EXPENDITURE               1224
# CAPITAL_OUTLAY_EXPENDITURE      1275
# GRADES_PK_G                     1542
# GRADES_KG_G                     1632
# GRADES_4_G                      1632
# GRADES_8_G                      1632
# GRADES_12_G                     1632
# GRADES_1_8_G                    1020
# GRADES_9_12_G                   1071
# GRADES_ALL_G                    1632
# AVG_MATH_4_SCORE                 565
# AVG_MATH_8_SCORE                 602
# AVG_READING_4_SCORE              650
# AVG_READING_8_SCORE              562
# dtype: int64

# %%
df.rename({
    'GRADES_PK_G':'enroll_kinder',
    'GRADES_KG_G':'enroll_kinder',
    'GRADES_4_G':'enroll_4',
    'GRADES_8_G':'enroll_8',
    'GRADES_12_G':'enroll_12',
    'GRADES_1_8_G':'enroll_primary',
    'GRADES_9_12_G':'enroll_hs',
    'GRADES_ALL_G':'enroll_all',
    'ENROLL':'ENROLL_ALL_EST'
    },
    axis=1,inplace=True)
def standardize_names(df):
    df.rename(mapper = str.lower, axis = 1, inplace=True)
    return df
df = standardize_names(df)
df.head()
# Out:
#        primary_key       state  year  enroll_all_est  total_revenue  \
# 0     1992_ALABAMA     ALABAMA  1992             NaN      2678885.0
# 1      1992_ALASKA      ALASKA  1992             NaN      1049591.0
# 2     1992_ARIZONA     ARIZONA  1992             NaN      3258079.0
# 3    1992_ARKANSAS    ARKANSAS  1992             NaN      1711959.0
# 4  1992_CALIFORNIA  CALIFORNIA  1992             NaN     26260025.0
#
#    federal_revenue  state_revenue  local_revenue  total_expenditure  \
# 0         304177.0      1659028.0       715680.0          2653798.0
# 1         106780.0       720711.0       222100.0           972488.0
# 2         297888.0      1369815.0      1590376.0          3401580.0
# 3         178571.0       958785.0       574603.0          1743022.0
# 4        2072470.0     16546514.0      7641041.0         27138832.0
#
#    instruction_expenditure  ...  enroll_4  enroll_8  enroll_12  \
# 0                1481703.0  ...   57948.0   58025.0    41167.0
# ...

# %%
#Dropping the rows without data about the math tests scores in 8th grade
df.dropna(subset = ['avg_math_8_score'], inplace = True)
df.count()
# Out:
# primary_key                     602
# state                           602
# year                            602
# enroll_all_est                  397
# total_revenue                   439
# federal_revenue                 439
# state_revenue                   439
# local_revenue                   439
# total_expenditure               439
# instruction_expenditure         439
# support_services_expenditure    439
# other_expenditure               397
# capital_outlay_expenditure      439
# enroll_kinder                   518
# enroll_kinder                   528
# enroll_4                        528
# enroll_8                        528
# enroll_12                       528
# enroll_primary                  397
# enroll_hs                       448
# enroll_all                      528
# avg_math_4_score                564
# avg_math_8_score                602
# avg_reading_4_score             521
# avg_reading_8_score             478
# dtype: int64

# %%
#Looking at the estimated and recorded enrollment to see if one can be used to fill the other
((df.enroll_all_est - df.enroll_all)/df.enroll_all).describe()
# Out:
# count    397.000000
# mean      -0.025946
# std        0.051301
# min       -0.450693
# 25%       -0.031392
# 50%       -0.013523
# 75%       -0.003988
# max        0.096404
# dtype: float64

# %%
#The standard deviation is not so high so we can fill a couple of missing estimates, 
#the rest is taken care of with the mean
df.enroll_all_est = df.enroll_all_est.fillna(df.enroll_all)
df.enroll_all_est = df.enroll_all_est.fillna(df.enroll_all_est.mean())
df.count()
# Out:
# primary_key                     602
# state                           602
# year                            602
# enroll_all_est                  602
# total_revenue                   439
# federal_revenue                 439
# state_revenue                   439
# local_revenue                   439
# total_expenditure               439
# instruction_expenditure         439
# support_services_expenditure    439
# other_expenditure               397
# capital_outlay_expenditure      439
# enroll_kinder                   518
# enroll_kinder                   528
# enroll_4                        528
# enroll_8                        528
# enroll_12                       528
# enroll_primary                  397
# enroll_hs                       448
# enroll_all                      528
# avg_math_4_score                564
# avg_math_8_score                602
# avg_reading_4_score             521
# avg_reading_8_score             478
# dtype: int64

# %%
#Missing values in the expenditure: fill the 'other expenditure', which has more missing values, 
#with the total minus all the others
df.other_expenditure = df.other_expenditure.fillna(df.total_expenditure - df.instruction_expenditure 
                                                   - df.support_services_expenditure 
                                                   - df.capital_outlay_expenditure)
#Rest of missing values with mean
df.other_expenditure = df.other_expenditure.fillna(df.other_expenditure.mean())
df.instruction_expenditure = df.instruction_expenditure.fillna(df.instruction_expenditure.mean())
df.support_services_expenditure = df.support_services_expenditure.fillna(df.support_services_expenditure.mean())
df.capital_outlay_expenditure = df.capital_outlay_expenditure.fillna(df.capital_outlay_expenditure.mean())
#Total expenditure missing values as the sum of the others so that it still has the same meaning
df.total_expenditure = df.total_expenditure.fillna(df.instruction_expenditure +
                                                  df.support_services_expenditure+
                                                  df.capital_outlay_expenditure+
                                                  df.other_expenditure)
df.count()
# Out:
# primary_key                     602
# state                           602
# year                            602
# enroll_all_est                  602
# total_revenue                   439
# federal_revenue                 439
# state_revenue                   439
# local_revenue                   439
# total_expenditure               602
# instruction_expenditure         602
# support_services_expenditure    602
# other_expenditure               602
# capital_outlay_expenditure      602
# enroll_kinder                   518
# enroll_kinder                   528
# enroll_4                        528
# enroll_8                        528
# enroll_12                       528
# enroll_primary                  397
# enroll_hs                       448
# enroll_all                      528
# avg_math_4_score                564
# avg_math_8_score                602
# avg_reading_4_score             521
# avg_reading_8_score             478
# dtype: int64

# %%
#Missing values in the revenue data: fill the state, federal and local revenues missing values 
#with the mean of the other values and sum them up for the total revenus missing values
df.federal_revenue = df.federal_revenue.fillna(df.federal_revenue.mean())
df.state_revenue = df.state_revenue.fillna(df.state_revenue.mean())
df.local_revenue = df.local_revenue.fillna(df.local_revenue.mean())
df.total_revenue = df.total_revenue.fillna(df.local_revenue +
                                          df.state_revenue +
                                          df.federal_revenue)
df.count()
# Out:
# primary_key                     602
# state                           602
# year                            602
# enroll_all_est                  602
# total_revenue                   602
# federal_revenue                 602
# state_revenue                   602
# local_revenue                   602
# total_expenditure               602
# instruction_expenditure         602
# support_services_expenditure    602
# other_expenditure               602
# capital_outlay_expenditure      602
# enroll_kinder                   518
# enroll_kinder                   528
# enroll_4                        528
# enroll_8                        528
# enroll_12                       528
# enroll_primary                  397
# enroll_hs                       448
# enroll_all                      528
# avg_math_4_score                564
# avg_math_8_score                602
# avg_reading_4_score             521
# avg_reading_8_score             478
# dtype: int64

# %% [markdown]
# <h2> Feature Selection </h2>
#
# _Use this space to modify or create features_

# %%
df['total_revenue_per_student'] = df['total_revenue']/df['enroll_all_est']
df['local_revenue_per_student'] = df['local_revenue']/df['enroll_all_est']
df['total_expenditure_per_student'] = df['total_expenditure']/df['enroll_all_est']
df['instruction_expenditure_per_student'] = df['instruction_expenditure']/df['enroll_all_est']

# %% [markdown]
# Final feature list: total_revenue_per_student,  local_revenue_per_student, total_expenditure_per_student, instruction_expenditure_per_student,  avg_math_8_score, year, state

# %% [markdown]
# Feature selection justification: I want to see the influence of the revenue and expenditure on the average math score in 8th grade.

# %% [markdown]
# <h2> EDA </h2>

# %% [markdown]
# Visualization 1

# %%
df.avg_math_8_score.hist()
plt.xlabel('score')
plt.ylabel('Frequency')
plt.title('Distribution of 8th grade math scores')
# Out:
# Text(0.5, 1.0, 'Distribution of 8th grade math scores')

# %% [markdown]
# Distribution of 8th grade math scores

# %% [markdown]
# Visualization 2

# %%
df.groupby('year').avg_math_8_score.mean().plot()
plt.ylabel('Math score')
plt.xlabel('Year')
plt.title('8th grade math score over time')
# Out:
# Text(0.5, 1.0, '8th grade math score over time')

# %% [markdown]
# 8th grade math score over time

# %%
df.set_index('year').groupby('state').avg_math_8_score.plot()
plt.ylabel('Math score')
plt.title('8th grade math score over time, by state')
# Out:
# Text(0.5, 1.0, '8th grade math score over time, by state')

# %% [markdown]
# We see that there are huge discrepancies in math scores between states. Obviously the time has also a great influence on the scores (students trained (only) to do well in tests?)

# %%
import seaborn as sns
sns.set()
sns.scatterplot(data= df, x='total_revenue_per_student', y='avg_math_8_score')
# Out:
# <AxesSubplot:xlabel='total_revenue_per_student', ylabel='avg_math_8_score'>

# %%
sns.scatterplot(data= df, x='local_revenue_per_student', y='avg_math_8_score')
# Out:
# <AxesSubplot:xlabel='local_revenue_per_student', ylabel='avg_math_8_score'>

# %%
sns.scatterplot(data= df, x='total_expenditure_per_student', y='avg_math_8_score')
# Out:
# <AxesSubplot:xlabel='total_expenditure_per_student', ylabel='avg_math_8_score'>

# %%
sns.scatterplot(data= df, x='instruction_expenditure_per_student', y='avg_math_8_score')
# Out:
# <AxesSubplot:xlabel='instruction_expenditure_per_student', ylabel='avg_math_8_score'>

# %%
sns.scatterplot(data = df, x='total_revenue_per_student', y='total_expenditure_per_student')
# Out:
# <AxesSubplot:xlabel='total_revenue_per_student', ylabel='total_expenditure_per_student'>

# %%
sns.scatterplot(data = df, x='total_revenue_per_student', y='instruction_expenditure_per_student')
# Out:
# <AxesSubplot:xlabel='total_revenue_per_student', ylabel='instruction_expenditure_per_student'>

# %%
sns.scatterplot(data = df, x='total_revenue_per_student', y='local_revenue_per_student')
# Out:
# <AxesSubplot:xlabel='total_revenue_per_student', ylabel='local_revenue_per_student'>

# %%
sns.scatterplot(data = df, x='local_revenue_per_student', y='instruction_expenditure_per_student')
# Out:
# <AxesSubplot:xlabel='local_revenue_per_student', ylabel='instruction_expenditure_per_student'>

# %% [markdown]
# Given the 4 previous plots we can reduce the number of features: the expenditures are perfectly predictable with the total revenue per student so we only keep this feature among these 3 features.
# We will also keep the local revenue per student.

# %% [markdown]
# <h2> Data Creation </h2>
#
# _Use this space to create train/test data_

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['local_revenue_per_student','total_revenue_per_student',
        'year']]
y = df.loc[X.index]['avg_math_8_score']

# %%
X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.2, random_state=0)

# %% [markdown]
# <h2> Prediction </h2>

# %% [markdown]
# Chosen ML task: Regression

# %%
# import your sklearn class here
from sklearn.linear_model import LinearRegression

# %%
# create your model here
model = LinearRegression()

# %%
model.fit(X_train, y_train)
print(model.intercept_)
print(model.coef_)
# Out:
# -1050.2496996008115
# [-0.38332426  0.11630112  0.6621976 ]

# %%
y_pred = model.predict(X_test)
model.score(X_test, y_test)
# Out:
# 0.33344636979708886

# %% [markdown]
# Not very good at predicting anything...

# %%
# FOR REGRESSION ONLY: (pick a single column to visualize results)

# Results from this graph _should not_ be used as a part of your results -- it is just here to help with intuition. 
# Instead, look at the error values and individual intercepts.


col_name = 'total_revenue_per_student'
col_index = X_train.columns.get_loc(col_name)

f = plt.figure(figsize=(12,6))
plt.scatter(X_train[col_name], y_train, color = "red")
plt.scatter(X_train[col_name], model.predict(X_train), color = "green")
plt.scatter(X_test[col_name], model.predict(X_test), color = "blue")

new_x = np.linspace(X_train[col_name].min(),X_train[col_name].max(),200)
intercept = model.predict([X_train.sort_values(col_name).iloc[0]]) - X_train[col_name].min()*model.coef_[col_index]
plt.plot(new_x, intercept+new_x*model.coef_[col_index])

plt.legend(['controlled model','true training','predicted training','predicted testing'])
plt.xlabel(col_name)
plt.ylabel('Instruction expenditure per student')
# Out:
# Text(0, 0.5, 'Instruction expenditure per student')

# %% [markdown]
# <h2> Classification </h2>

# %%
#Best students in math
y = df.loc[X.index]['avg_math_8_score']>285
X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=.3, random_state=0)
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=3)
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# FOR CLASSIFICATION ONLY:
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(model, X_test, y_test,
                         cmap=plt.cm.Blues)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score
accuracy_score(y_test, model.predict(X_test))
# Out:
# 0.6961325966850829

# %% [markdown]
# Better!

# %%
precision_score(y_test, model.predict(X_test))
# Out:
# 0.48717948717948717

# %%
recall_score(y_test, model.predict(X_test))
# Out:
# 0.35185185185185186

# %% [markdown]
# <h2> Summary </h2>

# %% [markdown]
# I looked at the influence of revenue and expenditure (per student) on the math scores in 8th grade. Most features do not really add information, they are redondant. Taking only one sort of expenditure or revenue will increase the precision and accuracy of an ML model trying to predict the math scores. Time and states have a greater influence on the scores.
